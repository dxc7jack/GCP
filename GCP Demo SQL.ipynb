# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- -----------
# absl-py                               1.2.0
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.6.1
# apache-beam                           2.28.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# asn1crypto                            1.5.1
# astunparse                            1.6.3
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 22.1.0
# avro-python3                          1.9.2.1
# Babel                                 2.10.3
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.11.1
# black                                 22.6.0
# bleach                                5.0.1
# blinker                               1.4
# brotlipy                              0.7.0
# cachetools                            4.2.4
# certifi                               2022.6.15.2
# cffi                                  1.15.1
# charset-normalizer                    2.1.1
# click                                 8.1.3
# cloud-tpu-client                      0.10
# cloud-tpu-profiler                    2.3.0
# cloudpickle                           2.2.0
# colorama                              0.4.5
# conda                                 4.14.0
# conda-content-trust                   0+unknown
# conda-package-handling                1.8.1
# crcmod                                1.7
# cryptography                          37.0.4
# cycler                                0.11.0
# debugpy                               1.6.3
# decorator                             5.1.1
# defusedxml                            0.7.1
# Deprecated                            1.2.13
# dill                                  0.3.1.1
# distlib                               0.3.6
# dm-tree                               0.1.7
# docker                                5.0.3
# docker-pycreds                        0.4.0
# docopt                                0.6.2
# docstring-parser                      0.15
# entrypoints                           0.4
# explainable-ai-sdk                    1.3.3
# explainers                            0.1
# fairness-indicators                   0.26.0
# fastavro                              1.6.1
# fasteners                             0.17.3
# fastjsonschema                        2.16.1
# filelock                              3.8.0
# fire                                  0.4.0
# flit_core                             3.7.1
# fonttools                             4.37.1
# frozenlist                            1.3.1
# fsspec                                2022.8.2
# future                                0.18.2
# gast                                  0.3.3
# gcsfs                                 2022.8.2
# gitdb                                 4.0.9
# GitPython                             3.1.27
# google-api-core                       2.8.1
# google-api-python-client              1.12.11
# google-apitools                       0.5.31
# google-auth                           1.35.0
# google-auth-httplib2                  0.1.0
# google-auth-oauthlib                  0.4.6
# google-cloud-aiplatform               1.17.0
# google-cloud-appengine-logging        1.1.4
# google-cloud-audit-log                0.2.4
# google-cloud-bigquery                 2.34.4
# google-cloud-bigquery-storage         2.15.0
# google-cloud-bigtable                 2.11.3
# google-cloud-build                    2.0.2
# google-cloud-core                     2.3.2
# google-cloud-dataproc                 5.0.1
# google-cloud-datastore                2.8.1
# google-cloud-dlp                      1.0.2
# google-cloud-firestore                2.6.1
# google-cloud-kms                      2.12.1
# google-cloud-language                 2.5.2
# google-cloud-logging                  3.2.2
# google-cloud-monitoring               2.11.1
# google-cloud-notebooks                1.4.2
# google-cloud-pipeline-components      1.0.21
# google-cloud-pubsub                   2.13.6
# google-cloud-pubsublite               1.4.3
# google-cloud-recommendations-ai       0.7.1
# google-cloud-resource-manager         1.6.1
# google-cloud-scheduler                2.7.1
# google-cloud-spanner                  3.20.0
# google-cloud-speech                   2.15.1
# google-cloud-storage                  1.44.0
# google-cloud-tasks                    2.10.2
# google-cloud-translate                3.8.2
# google-cloud-videointelligence        2.8.1
# google-cloud-vision                   3.1.1
# google-crc32c                         1.1.2
# google-pasta                          0.2.0
# google-resumable-media                2.3.3
# googleapis-common-protos              1.56.4
# greenlet                              1.1.3
# grpc-google-iam-v1                    0.12.4
# grpcio                                1.48.1
# grpcio-gcp                            0.2.2
# grpcio-status                         1.48.1
# gviz-api                              1.10.0
# h5py                                  2.10.0
# hdfs                                  2.7.0
# horovod                               0.23.0
# htmlmin                               0.1.12
# httplib2                              0.20.4
# idna                                  3.3
# ImageHash                             4.3.0
# imageio                               2.21.3
# importlib-metadata                    4.11.4
# importlib-resources                   5.9.0
# ipykernel                             6.15.3
# ipython                               7.33.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.3.9
# ipywidgets                            7.7.2
# jaraco.classes                        3.2.2
# jedi                                  0.18.1
# jeepney                               0.8.0
# Jinja2                                2.11.3
# joblib                                1.0.1
# json5                                 0.9.5
# jsonschema                            3.2.0
# jupyter                               1.0.0
# jupyter_client                        7.3.5
# jupyter-console                       6.4.4
# jupyter_core                          4.11.1
# jupyter-http-over-ws                  0.0.8
# jupyter-server                        1.18.1
# jupyter-server-mathjax                0.2.6
# jupyter-server-proxy                  3.2.2
# jupyterlab                            3.2.9
# jupyterlab-git                        0.39.2
# jupyterlab-pygments                   0.2.2
# jupyterlab-server                     2.10.3
# jupyterlab-widgets                    1.1.1
# jupytext                              1.14.0
# Keras                                 2.4.0
# Keras-Preprocessing                   1.1.2
# keras-tuner                           1.0.1
# keyring                               23.9.1
# keyrings.google-artifactregistry-auth 1.1.1
# kfp                                   1.8.13
# kfp-pipeline-spec                     0.1.16
# kfp-server-api                        1.8.5
# kiwisolver                            1.4.4
# kubernetes                            11.0.0
# libcst                                0.4.7
# llvmlite                              0.38.1
# lxml                                  4.9.1
# Markdown                              3.4.1
# markdown-it-py                        2.1.0
# MarkupSafe                            2.1.1
# matplotlib                            3.5.3
# matplotlib-inline                     0.1.6
# mdit-py-plugins                       0.3.0
# mdurl                                 0.1.0
# missingno                             0.4.2
# mistune                               0.8.4
# ml-metadata                           0.26.0
# ml-pipelines-sdk                      0.26.3
# mock                                  2.0.0
# more-itertools                        8.14.0
# multidict                             6.0.2
# multimethod                           1.4
# munkres                               1.1.4
# mypy-extensions                       0.4.3
# nb-conda                              2.2.1
# nb-conda-kernels                      2.3.1
# nbclassic                             0.4.3
# nbclient                              0.5.13
# nbconvert                             6.4.5
# nbdime                                3.1.1
# nbformat                              5.5.0
# nest-asyncio                          1.5.5
# networkx                              2.7.1
# notebook                              6.4.12
# notebook-executor                     0.2
# notebook-shim                         0.1.0
# numba                                 0.55.2
# numpy                                 1.18.5
# oauth2client                          4.1.3
# oauthlib                              3.2.1
# opt-einsum                            3.3.0
# orjson                                3.8.0
# overrides                             6.2.0
# packaging                             21.3
# pandas                                1.3.5
# pandas-profiling                      3.1.0
# pandocfilters                         1.5.0
# papermill                             2.3.4
# parso                                 0.8.3
# pathspec                              0.10.1
# patsy                                 0.5.2
# pbr                                   5.10.0
# pexpect                               4.8.0
# phik                                  0.12.2
# pickleshare                           0.7.5
# Pillow                                9.2.0
# pip                                   22.2.2
# pkgutil_resolve_name                  1.3.10
# platformdirs                          2.5.2
# plotly                                5.10.0
# pluggy                                1.0.0
# ply                                   3.11
# prettytable                           3.4.1
# prometheus-client                     0.14.1
# promise                               2.3
# prompt-toolkit                        3.0.31
# proto-plus                            1.22.1
# protobuf                              3.19.5
# psutil                                5.9.2
# ptyprocess                            0.7.0
# pyarrow                               9.0.0
# pyasn1                                0.4.8
# pyasn1-modules                        0.2.7
# pycosat                               0.6.3
# pycparser                             2.21
# pydantic                              1.10.2
# pydot                                 1.4.2
# Pygments                              2.13.0
# PyJWT                                 2.4.0
# pymongo                               3.12.3
# pyOpenSSL                             22.0.0
# pyparsing                             3.0.9
# PyQt5                                 5.15.7
# PyQt5-sip                             12.11.0
# pyrsistent                            0.18.1
# PySocks                               1.7.1
# python-dateutil                       2.8.2
# pytz                                  2022.2.1
# pyu2f                                 0.1.5
# PyWavelets                            1.3.0
# PyYAML                                5.4.1
# pyzmq                                 23.2.1
# qtconsole                             5.3.2
# QtPy                                  2.2.0
# requests                              2.28.1
# requests-oauthlib                     1.3.1
# requests-toolbelt                     0.9.1
# retrying                              1.3.3
# rsa                                   4.9
# ruamel-yaml-conda                     0.15.100
# scikit-image                          0.19.3
# scikit-learn                          1.0.2
# scipy                                 1.7.3
# seaborn                               0.12.0
# SecretStorage                         3.3.3
# Send2Trash                            1.8.0
# setuptools                            59.8.0
# simpervisor                           0.4
# sip                                   6.6.2
# six                                   1.16.0
# smmap                                 3.0.5
# sniffio                               1.3.0
# soupsieve                             2.3.2.post1
# SQLAlchemy                            1.4.41
# sqlparse                              0.4.2
# statsmodels                           0.13.2
# strip-hints                           0.1.10
# tabulate                              0.8.10
# tangled-up-in-unicode                 0.1.0
# tenacity                              8.0.1
# tensorboard                           2.3.0
# tensorboard-data-server               0.6.1
# tensorboard-plugin-profile            2.3.0
# tensorboard-plugin-wit                1.8.1
# tensorflow                            2.3.4
# tensorflow-cloud                      0.1.13
# tensorflow-data-validation            0.26.1
# tensorflow-datasets                   3.0.0
# tensorflow-estimator                  2.3.0
# tensorflow-hub                        0.9.0
# tensorflow-io                         0.15.0
# tensorflow-metadata                   0.26.0
# tensorflow-model-analysis             0.26.1
# tensorflow-probability                0.11.0
# tensorflow-serving-api                2.3.0
# tensorflow-transform                  0.26.0
# termcolor                             2.0.1
# terminado                             0.15.0
# terminaltables                        3.1.10
# testpath                              0.6.0
# textwrap3                             0.9.2
# tfx                                   0.26.3
# tfx-bsl                               0.26.1
# threadpoolctl                         3.1.0
# tifffile                              2021.11.2
# tinycss2                              1.1.1
# toml                                  0.10.2
# tomli                                 2.0.1
# toolz                                 0.12.0
# tornado                               6.2
# tqdm                                  4.64.1
# traitlets                             5.4.0
# typed-ast                             1.5.4
# typer                                 0.6.1
# typing_extensions                     4.3.0
# typing-inspect                        0.8.0
# unicodedata2                          14.0.0
# uritemplate                           3.0.1
# urllib3                               1.26.11
# virtualenv                            20.16.5
# visions                               0.7.4
# wcwidth                               0.2.5
# webencodings                          0.5.1
# websocket-client                      1.4.1
# Werkzeug                              2.2.2
# wheel                                 0.37.1
# widgetsnbextension                    3.6.1
# witwidget                             1.7.0
# wrapt                                 1.14.1
# yarl                                  1.7.2
# zipp                                  3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_29844/2221319454.py in <module>
#       1 import pandas as pd
# ----> 2 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 4.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.18.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from xgboost) (1.7.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 10
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 836.52query/s]
# Downloading: 100%|██████████| 10/10 [00:01<00:00,  7.63rows/s]
#    tree_id    legal_status                                    species address  \
# 0    48142  Permitted Site                                 Tree(s) ::    None
# 1    44866  Permitted Site                                 Tree(s) ::    None
# 2    34921  Permitted Site                                 Tree(s) ::    None
# 3    45916  Permitted Site                                 Tree(s) ::    None
# 4    97355  Permitted Site                                 Tree(s) ::    None
# 5    33929  Permitted Site                                 Tree(s) ::    None
# 6    44989  Permitted Site                                 Tree(s) ::    None
# 7    34903  Permitted Site  Magnolia grandiflora :: Southern Magnolia    None
# 8    44943  Permitted Site                                 Tree(s) ::    None
# 9    45011  Permitted Site                                 Tree(s) ::    None
#
#    site_order                     site_info plant_type care_taker  \
# 0         252  Sidewalk: Curb side : Cutout       Tree    Private
# 1          25  Sidewalk: Curb side : Cutout       Tree    Private
# 2           1  Sidewalk: Curb side : Cutout       Tree    Private
# 3          51  Sidewalk: Curb side : Cutout       Tree    Private
# 4           5      Unaccepted Street : Yard       Tree    Private
# 5           4  Sidewalk: Curb side : Cutout       Tree    Private
# 6          83  Sidewalk: Curb side : Cutout       Tree    Private
# 7           4  Sidewalk: Curb side : Cutout       Tree    Private
# 8         176  Sidewalk: Curb side : Cutout       Tree    Private
# 9          93  Sidewalk: Curb side : Cutout       Tree    Private
#
#   care_assistant                plant_date   dbh plot_size  \
# 0           None 2002-07-17 00:00:00+00:00  None      None
# 1           None 2001-04-25 00:00:00+00:00  None      None
# 2           None                       NaT  None      None
# 3           None 2001-12-06 00:00:00+00:00  None      None
# 4           None                       NaT  None      None
# 5           None 1997-03-25 00:00:00+00:00  None      None
# 6           None 2001-04-25 00:00:00+00:00  None      None
# 7           None 1997-09-05 00:00:00+00:00  None      None
# 8           None 2001-04-25 00:00:00+00:00  None      None
# 9           None 2001-04-25 00:00:00+00:00  None      None
#
#           permit_notes  x_coordinate  y_coordinate  latitude  longitude  \
# 0  Permit Number 45761           NaN           NaN       NaN        NaN
# 1  Permit Number 43922           NaN           NaN       NaN        NaN
# 2  Permit Number 38517           NaN           NaN       NaN        NaN
# 3  Permit Number 44451           NaN           NaN       NaN        NaN
# 4                 None           NaN           NaN       NaN        NaN
# 5  Permit Number 37893           NaN           NaN       NaN        NaN
# 6  Permit Number 43922           NaN           NaN       NaN        NaN
# 7  Permit Number 38505           NaN           NaN       NaN        NaN
# 8  Permit Number 43922           NaN           NaN       NaN        NaN
# 9  Permit Number 43922           NaN           NaN       NaN        NaN
#
#   location
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None

# %%
# %%bigquery df_tree
# SELECT species, count(*) as count, min(plant_date) as min_date, max(plant_date) as max_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees`
# group by 1 LIMIT 10
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1256.16query/s]
# Downloading: 100%|██████████| 10/10 [00:01<00:00,  8.68rows/s]

# %%
df_tree
# Out:
#                                           species  count  \
# 0                                      Tree(s) ::  11796
# 1       Magnolia grandiflora :: Southern Magnolia   6428
# 2  Platanus x hispanica :: Sycamore: London Plane  11740
# 3      Arbutus 'Marina' :: Hybrid Strawberry Tree   5761
# 4                Ginkgo biloba :: Maidenhair Tree   3275
# 5           Lophostemon confertus :: Brisbane Box   8885
# 6           Liriodendron tulipifera :: Tulip Tree    324
# 7    Melaleuca linariifolia :: Flaxleaf Paperbark    371
# 8   Metrosideros excelsa :: New Zealand Xmas Tree   8848
# 9                Prunus cerasifera :: Cherry Plum   6711
#
#                    min_date                  max_date
# 0 1955-09-19 00:00:00+00:00 2022-08-04 00:00:00+00:00
# 1 1955-12-13 00:00:00+00:00 2022-08-02 00:00:00+00:00
# 2 1956-02-15 00:00:00+00:00 2022-05-10 00:00:00+00:00
# 3 1956-02-06 00:00:00+00:00 2022-06-30 00:00:00+00:00
# 4 1956-02-06 00:00:00+00:00 2022-06-24 00:00:00+00:00
# 5 1969-07-28 00:00:00+00:00 2022-07-14 00:00:00+00:00
# 6 1986-08-21 00:00:00+00:00 2019-10-03 00:00:00+00:00
# 7 1973-08-15 00:00:00+00:00 2021-07-20 00:00:00+00:00
# 8 1956-06-14 00:00:00+00:00 2022-02-11 00:00:00+00:00
# 9 1970-03-04 00:00:00+00:00 2022-04-28 00:00:00+00:00
